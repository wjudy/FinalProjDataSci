# %%
from pandas import read_csv
from pandas import DataFrame
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# READING IN ALL DATA

ConservMarch2020 = read_csv("ConservMarch2020.csv", index_col=0)
LiberalsMarch2020 = read_csv("LiberalsMarch2020.csv", index_col=0)

DemocracyFeb2018 = read_csv("DemocracyFeb2018.csv", index_col=0)
DemocracyFeb2019 = read_csv("DemocracyFeb2019.csv", index_col=0)
DemocracyFeb2020 = read_csv("DemocracyFeb2020.csv", index_col=0)
DemocracyFeb2021 = read_csv("DemocracyFeb2021.csv", index_col=0)
DemocracyFeb2022 = read_csv("DemocracyFeb2022.csv", index_col=0)

DemocracyMarch2018 = read_csv("DemocracyMarch2018.csv", index_col=0)
DemocracyMarch2019 = read_csv("DemocracyMarch2019.csv", index_col=0)
DemocracyMarch2020 = read_csv("DemocracyMarch2020.csv", index_col=0)
DemocracyMarch2021 = read_csv("DemocracyMarch2021.csv", index_col=0)
DemocracyMarch2022 = read_csv("DemocracyMarch2022.csv", index_col=0)

DemocracyJan2020 = read_csv("DemocracyJan2020.csv", index_col=0)
DemocracyJan2021 = read_csv("DemocracyJan2021.csv", index_col=0)

FakeNewsFeb2018 = read_csv("FakeNewsFeb2018.csv", index_col=0)
FakeNewsFeb2020 = read_csv("FakeNewsFeb2020.csv", index_col=0)
FakeNewsFeb2021 = read_csv("FakeNewsFeb2021.csv", index_col=0)

FakeNewsMarch2018 = read_csv("FakeNewsMarch2018.csv", index_col=0)
FakeNewsMarch2020 = read_csv("FakeNewsMarch2020.csv", index_col=0)
FakeNewsMarch2021 = read_csv("FakeNewsMarch2021.csv", index_col=0)

# %%
# DEMOCRACY

# %%
# Setting up 2018

df18Pos = DemocracyFeb2018.iloc[:,2]  
df18Neg = DemocracyFeb2018.iloc[:,3]
df18Tot = DemocracyFeb2018.iloc[:,1]

df18PosTweets = df18Pos.multiply(df18Tot)
df18NegTweets = df18Neg.multiply(df18Tot)


dm18Pos = DemocracyMarch2018.iloc[:,2]  
dm18Neg = DemocracyMarch2018.iloc[:,3]
dm18Tot = DemocracyMarch2018.iloc[:,1]

dm18PosTweets = dm18Pos.multiply(dm18Tot)
dm18NegTweets = dm18Neg.multiply(dm18Tot)

# %%
# Setting up 2019

df19Pos = DemocracyFeb2019.iloc[:,2]  
df19Neg = DemocracyFeb2019.iloc[:,3]
df19Tot = DemocracyFeb2019.iloc[:,1]

df19PosTweets = df19Pos.multiply(df19Tot)
df19NegTweets = df19Neg.multiply(df19Tot)


dm19Pos = DemocracyMarch2019.iloc[:,2]  
dm19Neg = DemocracyMarch2019.iloc[:,3]
dm19Tot = DemocracyMarch2019.iloc[:,1]

dm19PosTweets = dm19Pos.multiply(dm19Tot)
dm19NegTweets = dm19Neg.multiply(dm19Tot)

# %%
# Setting up 2020

df20Pos = DemocracyFeb2020.iloc[:,2]  
df20Neg = DemocracyFeb2020.iloc[:,3]
df20Tot = DemocracyFeb2020.iloc[:,1]

df20PosTweets = df20Pos.multiply(df20Tot)
df20NegTweets = df20Neg.multiply(df20Tot)


dm20Pos = DemocracyMarch2020.iloc[:,2]  
dm20Neg = DemocracyMarch2020.iloc[:,3]
dm20Tot = DemocracyMarch2020.iloc[:,1]

dm20PosTweets = dm20Pos.multiply(dm20Tot)
dm20NegTweets = dm20Neg.multiply(dm20Tot)

# January
dj20Pos = DemocracyJan2020.iloc[:,2]  
dj20Neg = DemocracyJan2020.iloc[:,3]
dj20Tot = DemocracyJan2020.iloc[:,1]

dj20PosTweets = dj20Pos.multiply(dj20Tot)
dj20NegTweets = dj20Neg.multiply(dj20Tot)

# %%
# Setting up 2021

df21Pos = DemocracyFeb2021.iloc[:,2]  
df21Neg = DemocracyFeb2021.iloc[:,3]
df21Tot = DemocracyFeb2021.iloc[:,1]

df21PosTweets = df21Pos.multiply(df21Tot)
df21NegTweets = df21Neg.multiply(df21Tot)


dm21Pos = DemocracyMarch2021.iloc[:,2]  
dm21Neg = DemocracyMarch2021.iloc[:,3]
dm21Tot = DemocracyMarch2021.iloc[:,1]

dm21PosTweets = dm21Pos.multiply(dm21Tot)
dm21NegTweets = dm21Neg.multiply(dm21Tot)

# January
dj21Pos = DemocracyJan2021.iloc[:,2]  
dj21Neg = DemocracyJan2021.iloc[:,3]
dj21Tot = DemocracyJan2021.iloc[:,1]

dj21PosTweets = dj21Pos.multiply(dj21Tot)
dj21NegTweets = dj21Neg.multiply(dj21Tot)

# %%
# Setting up 2022

df22Pos = DemocracyFeb2022.iloc[:,2]  
df22Neg = DemocracyFeb2022.iloc[:,3]
df22Tot = DemocracyFeb2022.iloc[:,1]

df22PosTweets = df22Pos.multiply(df22Tot)
df22NegTweets = df22Neg.multiply(df22Tot)


dm22Pos = DemocracyMarch2022.iloc[:,2]  
dm22Neg = DemocracyMarch2022.iloc[:,3]
dm22Tot = DemocracyMarch2022.iloc[:,1]

dm22PosTweets = dm22Pos.multiply(dm22Tot)
dm22NegTweets = dm22Neg.multiply(dm22Tot)

# %%
# NOW FOR FAKE NEWS

# %%
# Setting up 2018

fnf18Pos = FakeNewsFeb2018.iloc[:,2]  
fnf18Neg = FakeNewsFeb2018.iloc[:,3]
fnf18Tot = FakeNewsFeb2018.iloc[:,1]

fnf18PosTweets = fnf18Pos.multiply(fnf18Tot)
fnf18NegTweets = fnf18Neg.multiply(fnf18Tot)


fnm18Pos = FakeNewsMarch2018.iloc[:,2]  
fnm18Neg = FakeNewsMarch2018.iloc[:,3]
fnm18Tot = FakeNewsMarch2018.iloc[:,1]

fnm18PosTweets = fnm18Pos.multiply(fnm18Tot)
fnm18NegTweets = fnm18Neg.multiply(fnm18Tot)

# %%
# Setting up 2020

fnf20Pos = FakeNewsFeb2020.iloc[:,2]  
fnf20Neg = FakeNewsFeb2020.iloc[:,3]
fnf20Tot = FakeNewsFeb2020.iloc[:,1]

fnf20PosTweets = fnf20Pos.multiply(fnf20Tot)
fnf20NegTweets = fnf20Neg.multiply(fnf20Tot)


fnm20Pos = FakeNewsMarch2020.iloc[:,2]  
fnm20Neg = FakeNewsMarch2020.iloc[:,3]
fnm20Tot = FakeNewsMarch2020.iloc[:,1]

fnm20PosTweets = fnm20Pos.multiply(fnm20Tot)
fnm20NegTweets = fnm20Neg.multiply(fnm20Tot)

# %%
# Setting up 2021

fnf21Pos = FakeNewsFeb2021.iloc[:,2]  
fnf21Neg = FakeNewsFeb2021.iloc[:,3]
fnf21Tot = FakeNewsFeb2021.iloc[:,1]

fnf21PosTweets = fnf21Pos.multiply(fnf20Tot)
fnf21NegTweets = fnf21Neg.multiply(fnf20Tot)


fnm21Pos = FakeNewsMarch2021.iloc[:,2]  
fnm21Neg = FakeNewsMarch2021.iloc[:,3]
fnm21Tot = FakeNewsMarch2021.iloc[:,1]

fnm21PosTweets = fnm21Pos.multiply(fnm21Tot)
fnm21NegTweets = fnm21Neg.multiply(fnm21Tot)

# %%
# Setting up CONSERVATIVES VS. LIBERALS

cm20Pos = ConservMarch2020.iloc[:,2]  
cm20Neg = ConservMarch2020.iloc[:,3]
cm20Tot = ConservMarch2020.iloc[:,1]

cm20PosTweets = cm20Pos.multiply(cm20Tot)
cm20NegTweets = cm20Neg.multiply(cm20Tot)


lm20Pos = LiberalsMarch2020.iloc[:,2]  
lm20Neg = LiberalsMarch2020.iloc[:,3]
lm20Tot = LiberalsMarch2020.iloc[:,1]

lm20PosTweets = lm20Pos.multiply(lm20Tot)
lm20NegTweets = lm20Neg.multiply(lm20Tot)

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2018
ax1.bar(range(len(df18Pos)), df18Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(df18Neg)), df18Neg, bottom=df18Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2018")
plt.legend(loc='upper left')

# MARCH 2018
ax2.bar(range(len(dm18Pos)), dm18Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(dm18Neg)), dm18Neg, bottom=dm18Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2018")
plt.legend(loc='upper left')



# FEB 2018 totals
ax3.bar(range(len(df18PosTweets)), df18PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(df18NegTweets)), df18NegTweets, bottom=df18PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,9000), yticks=np.arange(0, 9000, 900))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2018")
plt.legend(loc='upper left')

# MARCH 2018 totals
ax4.bar(range(len(dm18PosTweets)), dm18PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(dm18NegTweets)), dm18NegTweets, bottom=dm18PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,9000), yticks=np.arange(0, 9000, 900))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2018")
plt.legend(loc='upper left')

plt.savefig("Dem2018.png")

# %%
f1, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2019
ax1.bar(range(len(df19Pos)), df19Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(df19Neg)), df19Neg, bottom=df19Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2019")
plt.legend(loc='upper left')

# MARCH 2019
ax2.bar(range(len(dm19Pos)), dm19Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(dm19Neg)), dm19Neg, bottom=dm19Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2019")
plt.legend(loc='upper left')



# FEB 2019 totals
ax3.bar(range(len(df19PosTweets)), df19PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(df19NegTweets)), df19NegTweets, bottom=df19PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,3800), yticks=np.arange(0, 3800, 380))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2019")
plt.legend(loc='upper left')

# MARCH 2019 totals
ax4.bar(range(len(dm19PosTweets)), dm19PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(dm19NegTweets)), dm19NegTweets, bottom=dm19PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,3800), yticks=np.arange(0, 3800, 380))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2019")
plt.legend(loc='upper left')

plt.savefig("Dem2019.png")

# %%
f2, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2020
ax1.bar(range(len(df20Pos)), df20Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(df20Neg)), df20Neg, bottom=df20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2020")
plt.legend(loc='upper left')

# MARCH 2020
ax2.bar(range(len(dm20Pos)), dm20Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(dm20Neg)), dm20Neg, bottom=dm20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2020")
plt.legend(loc='upper left')



# FEB 2020 totals
ax3.bar(range(len(df20PosTweets)), df20PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(df20NegTweets)), df20NegTweets, bottom=df20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,5800), yticks=np.arange(0, 5800, 580))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2020")
plt.legend(loc='upper left')

# MARCH 2020 totals
ax4.bar(range(len(dm20PosTweets)), dm20PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(dm20NegTweets)), dm20NegTweets, bottom=dm20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,5800), yticks=np.arange(0,  5800, 580))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2020")
plt.legend(loc='upper left')

plt.savefig("Dem2020.png")

# %%
f3, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2021
ax1.bar(range(len(df21Pos)), df21Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(df21Neg)), df21Neg, bottom=df21Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2021")
plt.legend(loc='upper left')

# MARCH 2021
ax2.bar(range(len(dm21Pos)), dm21Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(dm21Neg)), dm21Neg, bottom=dm21Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2021")
plt.legend(loc='upper left')



# FEB 2021 totals
ax3.bar(range(len(df21PosTweets)), df21PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(df21NegTweets)), df21NegTweets, bottom=df21PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,14000), yticks=np.arange(0, 14000, 1400))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2021")
plt.legend(loc='upper left')

# MARCH 2021 totals
ax4.bar(range(len(dm21PosTweets)), dm21PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(dm21NegTweets)), dm21NegTweets, bottom=dm21PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,14000), yticks=np.arange(0,  14000, 1400))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2021")
plt.legend(loc='upper left')

plt.savefig('Dem2021.png')

# %%
f4, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2022
ax1.bar(range(len(df22Pos)), df22Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(df22Neg)), df22Neg, bottom=df22Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2022")
plt.legend(loc='upper left')

# MARCH 2022
ax2.bar(range(len(dm22Pos)), dm22Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(dm22Neg)), dm22Neg, bottom=dm22Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(.4,.8), yticks=np.arange(.4, .8, (.8-.4)/10))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2022")
plt.legend(loc='upper left')



# FEB 2022 totals
ax3.bar(range(len(df22PosTweets)), df22PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(df22NegTweets)), df22NegTweets, bottom=df22PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,5500), yticks=np.arange(0, 5500, 550))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2022")
plt.legend(loc='upper left')

# MARCH 2022 totals
ax4.bar(range(len(dm22PosTweets)), dm22PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(dm22NegTweets)), dm22NegTweets, bottom=dm22PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,5500), yticks=np.arange(0,  5500, 550))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2022")
plt.legend(loc='upper left')

plt.savefig("Dem2022.png")

# %%
f5, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2018
ax1.bar(range(len(fnf18Pos)), fnf18Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(fnf18Neg)), fnf18Neg, bottom=fnf18Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,.8), yticks=np.arange(0, .8, 0.08))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2018")
plt.legend(loc='upper left')

# MARCH 2018
ax2.bar(range(len(fnm18Pos)), fnm18Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(fnm18Neg)), fnm18Neg, bottom=fnm18Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,.8), yticks=np.arange(0, .8, .08))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2018")
plt.legend(loc='upper left')



# FEB 2018 totals
ax3.bar(range(len(fnf18PosTweets)), fnf18PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(fnf18NegTweets)), fnf18NegTweets, bottom=fnf18PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,1600), yticks=np.arange(0, 1600, 160))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2018")
plt.legend(loc='upper left')

# MARCH 2018 totals
ax4.bar(range(len(fnm18PosTweets)), fnm18PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(fnm18NegTweets)), fnm18NegTweets, bottom=fnm18PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,1600), yticks=np.arange(0,  1600, 160))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2018")
plt.legend(loc='upper left')

plt.savefig("FakeNews2018.png")

# %%
f6, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2020
ax1.bar(range(len(fnf20Pos)), fnf20Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(fnf20Neg)), fnf20Neg, bottom=fnf20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,.8), yticks=np.arange(0, .8, 0.08))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2020")
plt.legend(loc='upper left')

# MARCH 2020
ax2.bar(range(len(fnm20Pos)), fnm20Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(fnm20Neg)), fnm20Neg, bottom=fnm20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,.8), yticks=np.arange(0, .8, .08))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2020")
plt.legend(loc='upper left')



# FEB 2020 totals
ax3.bar(range(len(fnf20PosTweets)), fnf20PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(fnf20NegTweets)), fnf20NegTweets, bottom=fnf20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,2750), yticks=np.arange(0, 2750, 275))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2020")
plt.legend(loc='upper left')

# MARCH 2020 totals
ax4.bar(range(len(fnm20PosTweets)), fnm20PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(fnm20NegTweets)), fnm20NegTweets, bottom=fnm20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,2750), yticks=np.arange(0,  2750, 275))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2020")
plt.legend(loc='upper left')

plt.savefig("FakeNews2020.png")

# %%
f7, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# FEB 2021
ax1.bar(range(len(fnf21Pos)), fnf21Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(fnf21Neg)), fnf21Neg, bottom=fnf21Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,.8), yticks=np.arange(0, .8, 0.08))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("February 2021")
plt.legend(loc='upper left')

# MARCH 2021
ax2.bar(range(len(fnm21Pos)), fnm21Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(fnm21Neg)), fnm21Neg, bottom=fnm21Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,.8), yticks=np.arange(0, .8, .08))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("March 2021")
plt.legend(loc='upper left')



# FEB 2021 totals
ax3.bar(range(len(fnf21PosTweets)), fnf21PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(fnf21NegTweets)), fnf21NegTweets, bottom=fnf21PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,1250), yticks=np.arange(0, 1250, 125))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("February 2021")
plt.legend(loc='upper left')

# MARCH 2021 totals
ax4.bar(range(len(fnm21PosTweets)), fnm21PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(fnm21NegTweets)), fnm21NegTweets, bottom=fnm21PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,1250), yticks=np.arange(0,  1250, 125))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("March 2021")
plt.legend(loc='upper left')

plt.savefig("FakeNews2021.png")

# %%
f8, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(15,10))

# CONSERV
ax1.bar(range(len(cm20Pos)), cm20Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(cm20Neg)), cm20Neg, bottom=cm20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0.3,.5), yticks=np.arange(.3, .5, 0.02))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("Conservative Ratios")
plt.legend(loc='upper left')

# LIBERALS
ax2.bar(range(len(lm20Pos)), lm20Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(lm20Neg)), lm20Neg, bottom=lm20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0.3,.5), yticks=np.arange(.3, .5, .02))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("Liberal Ratios")
plt.legend(loc='upper left')

# COMPOSITE
# CONSERV
ax3.bar(range(len(cm20Pos)), cm20Pos, alpha=.5, color='g')
ax3.bar(range(len(cm20Neg)), cm20Neg, bottom=cm20Pos, alpha=.5, color='r')
plt.sca(ax3)

# LIBERALS
ax3.bar(range(len(lm20Pos)), lm20Pos, label='Positives', alpha=.5, color='g')
ax3.bar(range(len(lm20Neg)), lm20Neg, bottom=lm20Pos, label='Negavites', alpha=.5, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0.3,.5), yticks=np.arange(.3, .5, .02))
ax3.set_ylabel("Percentages")
ax3.set_xlabel("Days")
ax3.set_title("Composite Ratios")
plt.legend(loc='upper left')

# Conserv totals
ax4.bar(range(len(cm20PosTweets)), cm20PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(cm20NegTweets)), cm20NegTweets, bottom=cm20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,27), xticks = np.arange(0, 28, 5), ylim=(0,1100), yticks=np.arange(0, 1110, 110))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("Liberal Totals")
plt.legend(loc='upper left')

# Liberal totals
ax5.bar(range(len(lm20PosTweets)), lm20PosTweets, label='Positives', alpha=1, color='g')
ax5.bar(range(len(lm20NegTweets)), lm20NegTweets, bottom=lm20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax5)

ax5.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,1110), yticks=np.arange(0,  1110, 110))
ax5.set_ylabel("Total Tweets")
ax5.set_xlabel("Days")
ax5.set_title("Conservative Totals")
plt.legend(loc='upper left')

# COMPOSITE

# Conserv totals
ax6.bar(range(len(cm20PosTweets)), cm20PosTweets, alpha=.5, color='g')
ax6.bar(range(len(cm20NegTweets)), cm20NegTweets, bottom=cm20PosTweets, alpha=.5, color='r')
plt.sca(ax6)

# Liberal totals
ax6.bar(range(len(lm20PosTweets)), lm20PosTweets, label='Positives', alpha=.5, color='g')
ax6.bar(range(len(lm20NegTweets)), lm20NegTweets, bottom=lm20PosTweets, label='Negavites', alpha=.5, color='r')
plt.sca(ax6)

ax6.set(xlim=(0,31), xticks = np.arange(0, 31, 5), ylim=(0,1110), yticks=np.arange(0,  1110, 110))
ax6.set_ylabel("Total Tweets")
ax6.set_xlabel("Days")
ax6.set_title("Composite Totals")
plt.legend(loc='upper left')

plt.savefig("ConservLibs.png")

# %%
f9, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10,10))

# January 2020
ax1.bar(range(len(dj20Pos)), dj20Pos, label='Positives', alpha=1, color='g')
ax1.bar(range(len(dj20Neg)), dj20Neg, bottom=dj20Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax1)

ax1.set(xlim=(0,14), xticks = np.arange(0, 14, 3), ylim=(0.4,.8), yticks=np.arange(0.4, .8, 0.04))
ax1.set_ylabel("Percentages")
ax1.set_xlabel("Days")
ax1.set_title("January 2020")
plt.legend(loc='upper left')

# January 2021
ax2.bar(range(len(dj21Pos)), dj21Pos, label='Positives', alpha=1, color='g')
ax2.bar(range(len(dj21Neg)), dj21Neg, bottom=dj21Pos, label='Negavites', alpha=1, color='r')
plt.sca(ax2)

ax2.set(xlim=(0,14), xticks = np.arange(0, 14, 3), ylim=(0.4,.8), yticks=np.arange(.4, .8, .04))
ax2.set_ylabel("Percentages")
ax2.set_xlabel("Days")
ax2.set_title("January 2021")
plt.legend(loc='upper left')



# January 2020 totals
ax3.bar(range(len(dj20PosTweets)), dj20PosTweets, label='Positives', alpha=1, color='g')
ax3.bar(range(len(dj20NegTweets)), dj20NegTweets, bottom=dj20PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax3)

ax3.set(xlim=(0,14), xticks = np.arange(0, 14, 3), ylim=(0,50000), yticks=np.arange(0, 50000, 5000))
ax3.set_ylabel("Total Tweets")
ax3.set_xlabel("Days")
ax3.set_title("January 2020")
plt.legend(loc='upper left')

# January 2021 totals
ax4.bar(range(len(dj21PosTweets)), dj21PosTweets, label='Positives', alpha=1, color='g')
ax4.bar(range(len(dj21NegTweets)), dj21NegTweets, bottom=dj21PosTweets, label='Negavites', alpha=1, color='r')
plt.sca(ax4)

ax4.set(xlim=(0,14), xticks = np.arange(0, 14, 3), ylim=(0,50000), yticks=np.arange(0, 50000, 5000))
ax4.set_ylabel("Total Tweets")
ax4.set_xlabel("Days")
ax4.set_title("January 2021")
plt.legend(loc='upper left')
plt.savefig("DemJan.png")
